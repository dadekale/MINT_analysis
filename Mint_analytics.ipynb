# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_columns = None
# https://datatopics.worldbank.org/debt/ids/country/tur/counterpartarea/wld#

# %%
df = pd.read_csv("Dataset\Indonesia.csv", header=0, index_col=0)
df.columns = df.iloc[0, :]
df = df.transpose()
df.columns.values
# Out:
# array(['$ millions, unless otherwise indicated', nan,
#        '1. Summary external debt data', 'External debt stocks',
#        'Long-term external debt', 'Public and publicly guaranteed',
#        'Public sector', 'General Government', 'Other public sector',
#        'Private sector guaranteed by public sector',
#        'Private nonguaranteed', 'Use of IMF credit', 'SDR allocations',
#        'Short-term external debt', 'Official creditors',
#        'Private creditors', 'Official creditors', 'Private creditors',
#        'External debt flows', 'Disbursements', 'Long-term external debt',
#        'IMF purchases', 'Principal repayments', 'Long-term external debt',
#        'IMF repurchases', 'Net flows', 'Long-term external debt',
#        'Short-term external debt', 'Interest payments',
#        'Long-term external debt', 'IMF charges',
#        'Short-term external debt', 'Net transfers on external debt',
#        'Total debt service paid', 'Long-term external debt',
# ...

# %%
fig = plt.figure(figsize=(20, 10), dpi = 150)
plt.plot(df["$ millions, unless otherwise indicated"], df["External debt stocks"]/df["Public sector"])
#plt.plot(df["$ millions, unless otherwise indicated"], df["Private nonguaranteed"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\dadekale\Desktop\MINT analytics\Mint_analytics.ipynb Cell 3 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/dadekale/Desktop/MINT%20analytics/Mint_analytics.ipynb#ch0000002?line=0'>1</a> fig = plt.figure(figsize=(20, 10), dpi = 150)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dadekale/Desktop/MINT%20analytics/Mint_analytics.ipynb#ch0000002?line=1'>2</a> plt.plot(df["$ millions, unless otherwise indicated"], df["External debt stocks"]/df["Public sector"])
#
# File c:\Users\dadekale\Anaconda3\envs\data_analytics_env\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# ...
